# %% [markdown]
# # 第三回 繰り返し処理について

# %% [markdown]
# **開発環境**
# - Python3.7

# %% [markdown]
# 繰り返しとは、決まった回数や条件を満たしてれば、同じ処理を実行するプログラム構造です。

# %% [markdown]
# ## for文

# %% [markdown]
# 繰り返しの代表例が**`for文`**です。<br>
# **`for文`**は、条件を満たしていれば、同じ処理をぐるぐる繰り返します。<br>
# そして、条件を満たさなくなったタイミングで、繰り返しがおわります。

# %% [markdown]
# ![スクリーンショット 2021-02-05 10.51.54.png](attachment:3e2228fb-3742-427b-9522-c1eed116278f.png)

# %% [markdown]
# 例えば、for文で同じ処理を5回繰り返したい場合で考えてみます。<br>
# どうやったら5回をカウントできるでしょうか。

# %% [markdown]
# 例えば、「1」からスタートして、1ずつ増やしていき「5」で終われば、5回です。

# %% [markdown]
# ![スクリーンショット 2021-02-05 10.54.46.png](attachment:dd029162-9c47-43ef-b7be-a87898a53db0.png)

# %% [markdown]
# 例えば、「0」からスタートして、1ずつ増やしていき「4」で終われば、これも5回です。

# %% [markdown]
# ![スクリーンショット 2021-02-05 10.56.00.png](attachment:82110b68-2d42-4be8-b34d-d3bd492bc24f.png)

# %% [markdown]
# そういった処理をPythonのfor文で書いていきます。<br>
# Pythonでのfor文のきまりをみていきましょう。

# %% [markdown]
# ~~~
# for 変数 in range(繰り返し回数):
# 　繰り返し中に実行する処理
# ~~~

# %% [markdown]
# まずforを書きます。次に繰り返し回数を格納する変数を記述します。<br>

# %% [markdown]
# ここで定義した変数のことを**`カウンタ変数`**といいます。

# %% [markdown]
# for文では、繰り返し処理を**`カウンタ変数`**によって制御します。

# %% [markdown]
# 5回繰り返したい場合は、**`カウンタ変数`**に数字が順次代入され、5回目がきたら繰り返し処理が終わります。

# %% [markdown]
# カウンタ変数は、英語の「**`index`**」「**`Iterator`**」の頭文字「**` i `**」が使われることが多いです。

# %% [markdown]
# 次に**`in`**と書いて、**`range`**。丸括弧を書きます。<br>
# 丸括弧の中に繰り返したい回数を、数値で記述します。<br>

# %% [markdown]
# 最後に**`コロン`**を記述します。<br>
# **`コロン`**の次の行は**`インデント`**を下げて、繰り返したい処理を記述します。

# %% [markdown]
# 繰り返したい処理が終わったら、一番上に戻り、繰り返し処理が終わりになるか判定します。<br>
# 繰り返し回数分、繰り返していないなら、次のループをします。繰り返し回数分繰り返していたら、ループが終了します。

# %% [markdown]
# コードを書いてみましょう。

# %%
for i in range(5):
    print(i)

# %% [markdown]
# まず**`for`**を書きます。<br>
# 次に、繰り返しのデータを受け取るカウンタ変数「**`i`**」を定義します。

# %% [markdown]
# 次に**`in`**を記述し、繰り返し回数を**`range`**の丸括弧内に記述します。<br>
# **`range`**は0から4までの5つの数値のリストを作っているようなものと考えてください。

# %% [markdown]
# **`range`**で作ったリストの数値を、繰り返しのたびに変数**`i`**に先頭の0から格納していきます。<br>
# カウンタ変数「**`i`**」の変化がみれるように、print関数で**`i`**を表示させてみましょう。

# %% [markdown]
# 実行すると。「0」から「4」までが表示されます。

# %% [markdown]
# ### ■break文

# %% [markdown]
# 次に、**`break文`**についてです。

# %% [markdown]
# **`break文`**は、ある条件にあてはまったとき、繰り返し処理を終了させることができます。

# %% [markdown]
# 例えば、「0」からスタートさせて、1ずつ増やしていき、「3」になったら繰り返しを終了するといったときです。

# %% [markdown]
# コードを書いてみます。

# %%
for i in range(5):
    if i == 3:
        break
    print(i)

# %% [markdown]
# ここで、**`i`**が3にになったときに、**`break`**する記述をします。<br>
# 「3」でループを抜けるので、「0」から「2」まで表示されるはずです。

# %% [markdown]
# ### ■continue文

# %% [markdown]
# 次に、**`continue文`**についてです。

# %% [markdown]
# **`continue文`**は、繰り返し処理で、ある条件にあてはまったときにその処理をスキップしたい場合に使います。

# %% [markdown]
# 例えば、「0」からスタートさせて、1ずつ増やしていったとき、「3」になったら「3」をスキップさせるという場合です。

# %% [markdown]
# コードを書いてみます。

# %%
for i in range(5):
    if i == 3:
        continue
    print(i)

# %% [markdown]
# if文でiが3にになったときに、処理をスキップさせる**`continue`**を記述をします。

# %% [markdown]
# 「3」をスキップするので、「0」「1」「2」「4」が表示されるはずです。

# %% [markdown]
# ### ■for文のネスト

# %% [markdown]
# for文の中にfor文を入れることもできます。

# %% [markdown]
# あるものの中に、それと同じ種類のものが入っている構造のことをネストといいます。

# %% [markdown]
# **for文の中にfor文が入っている構造のことをfor文の`ネスト`といいます。**

# %% [markdown]
# 外側の繰り返しのカウンタ変数は「**`i`**」で、0から2まで回し、内側の繰り返しのカウンタ変数は「**`j`**」で、<br>
# 0から2まで回すという例で考えてみます。

# %% [markdown]
# 外側のループの1周目の時に、内側のループが0から2までまわります。<br>
# 内側のループがまわりきったら、外側のループが2周目に入ります。

# %% [markdown]
# コードを書いてみましょう。

# %%
for i in range(3):
    for j in range(3):
        print(i, j, sep="-")

# %% [markdown]
# iとjの変化がわかるように、「i、ハイフン、j」を表示させてみましょう。

# %% [markdown]
# printの第一引数、第二引数をそれぞれi、jにして、sep引数をハイフンにすることで、i、ハイフン、jと表示できます。

# %% [markdown]
# iが0周目のときに、jが0から2までまわり、次にiが1周目の動きになる予想通りの結果となります。
